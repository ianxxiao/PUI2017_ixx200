# %% [markdown]
# # Overview
#
# This is a python script that addresses the following questions:
#
# - What are the most popular departing and destination stations?
# - What are the common origination and arrival area clusters (not just based on Zip Code)?
# - What are the top 10 stations with the least number of bikes by the end of the day at 11 pm over the month of September?
# - What are the top 3 stations with the most number of bikes near each of the stations from question 3)?
# - Does bike stations encourage multi-modal travelling?
# - How many trips ends near a subway station?
#
# # Hypothesis Testing
# the average number of arrival trips is higher compared to the ones that are remote from any subway stations.
#
# # Outputs
# - Statistical and Graphical Analysis
# - Scenario Simulation
#
# # Key Methods
# - Pairwise Distance (http://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.pairwise_distances.html)
# - Spatial Visualization

# %% [markdown]
# ---
#
# ## Data Ingestion and Feature Engineering

# %%
import pandas as pd
import geopandas as gpd
pd.set_option('display.max_columns', 500)
import numpy as np
import matplotlib as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing
import warnings
import matplotlib.style as style
warnings.filterwarnings('ignore')
style.use('fivethirtyeight')

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
url = "https://s3.amazonaws.com/tripdata/JC-201709-citibike-tripdata.csv.zip"
df = pd.read_csv(url, compression = "zip")

# %%
url = "https://data.cityofnewyork.us/api/views/he7q-3hwy/rows.csv?accessType=DOWNLOAD"
subway = pd.read_csv(url)

# %%
df.shape
# Out:
# (33119, 15)

# %%
subway.shape
# Out:
# (1928, 5)

# %%
df.sample(10)
# Out:
#        tripduration            starttime             stoptime  \
# 7916           1081  2017-09-09 07:58:10  2017-09-09 08:16:12
# 8315            593  2017-09-09 14:13:40  2017-09-09 14:23:34
# 31768           370  2017-09-29 16:52:49  2017-09-29 16:58:59
# 15958           299  2017-09-15 18:12:57  2017-09-15 18:17:57
# 29599           239  2017-09-27 19:21:44  2017-09-27 19:25:43
# 14024           317  2017-09-14 09:11:14  2017-09-14 09:16:31
# 20876           183  2017-09-20 08:05:48  2017-09-20 08:08:51
# 13931           104  2017-09-14 08:30:19  2017-09-14 08:32:04
# 24919           419  2017-09-23 11:17:52  2017-09-23 11:24:51
# 14501           434  2017-09-14 17:49:54  2017-09-14 17:57:09
#
#        start station id start station name  start station latitude  \
# 7916               3203      Hamilton Park               40.727596
# 8315               3275     Columbus Drive               40.718355
# 31768              3202       Newport PATH               40.727224
# 15958              3183     Exchange Place               40.716247
# 29599              3213     Van Vorst Park               40.718489
# 14024              3209       Brunswick St               40.724176
# 20876              3279        Dixon Mills               40.721630
# 13931              3211         Newark Ave               40.721525
# 24919              3268     Lafayette Park               40.713464
# 14501              3202       Newport PATH               40.727224
#
#        start station longitude  end station id end station name  \
# 7916                -74.044247            3183   Exchange Place
# 8315                -74.038914            3199     Newport Pkwy
# 31768               -74.033759            3203    Hamilton Park
# 15958               -74.033459            3187        Warren St
# 29599               -74.047727            3185        City Hall
# 14024               -74.050656            3186    Grove St PATH
# 20876               -74.049968            3186    Grove St PATH
# 13931               -74.046305            3186    Grove St PATH
# 24919               -74.062859            3185        City Hall
# 14501               -74.033759            3203    Hamilton Park
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 7916              40.716247             -74.033459   29270  Subscriber
# 8315              40.728745             -74.032108   29442  Subscriber
# 31768             40.727596             -74.044247   29598  Subscriber
# 15958             40.721124             -74.038051   26223  Subscriber
# 29599             40.717733             -74.043845   30356  Subscriber
# 14024             40.719586             -74.043117   26220  Subscriber
# 20876             40.719586             -74.043117   29243  Subscriber
# 13931             40.719586             -74.043117   29265  Subscriber
# 24919             40.717733             -74.043845   29665  Subscriber
# 14501             40.727596             -74.044247   26229  Subscriber
#
#        birth year  gender
# 7916       1977.0       2
# 8315       1991.0       1
# 31768      1980.0       1
# 15958      1956.0       1
# 29599      1983.0       1
# 14024      1986.0       2
# 20876      1986.0       1
# 13931      1982.0       1
# 24919      1986.0       1
# 14501      1979.0       1

# %%
df['starttime'] = pd.to_datetime(df['starttime'], infer_datetime_format= True)
df['stoptime'] = pd.to_datetime(df['stoptime'], infer_datetime_format= True)

# %%
df['day'] = df['starttime'].dt.day
df['start_hour'] = df['starttime'].dt.hour
df['DOW'] = df['starttime'].dt.dayofweek

# %%
df.sample(10)
# Out:
#        tripduration           starttime            stoptime  start station id  \
# 20148           236 2017-09-19 13:44:42 2017-09-19 13:48:38              3199
# 3527            661 2017-09-05 09:05:30 2017-09-05 09:16:31              3277
# 17877           270 2017-09-17 14:55:17 2017-09-17 14:59:47              3203
# 20279           494 2017-09-19 17:45:40 2017-09-19 17:53:54              3183
# 23835           890 2017-09-22 11:09:38 2017-09-22 11:24:28              3206
# 113             121 2017-09-01 07:46:58 2017-09-01 07:48:59              3211
# 11462           531 2017-09-12 08:56:52 2017-09-12 09:05:43              3203
# 3738            386 2017-09-05 13:56:43 2017-09-05 14:03:10              3186
# 22324          1031 2017-09-21 08:42:01 2017-09-21 08:59:12              3212
# 28184           587 2017-09-26 12:02:27 2017-09-26 12:12:14              3205
#
#             start station name  start station latitude  \
# 20148             Newport Pkwy               40.728745
# 3527   Communipaw & Berry Lane               40.714358
# 17877            Hamilton Park               40.727596
# 20279           Exchange Place               40.716247
# 23835                  Hilltop               40.731169
# 113                 Newark Ave               40.721525
# 11462            Hamilton Park               40.727596
# 3738             Grove St PATH               40.719586
# 22324          Christ Hospital               40.734786
# 28184        JC Medical Center               40.716540
#
#        start station longitude  end station id   end station name  \
# 20148               -74.032108            3480       WS Don't Use
# 3527                -74.066611            3185          City Hall
# 17877               -74.044247            3186      Grove St PATH
# 20279               -74.033459            3199       Newport Pkwy
# 23835               -74.057574            3267       Morris Canal
# 113                 -74.046305            3186      Grove St PATH
# 11462               -74.044247            3205  JC Medical Center
# 3738                -74.043117            3202       Newport PATH
# 22324               -74.050444            3183     Exchange Place
# 28184               -74.049638            3202       Newport PATH
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 20148              0.000000               0.000000   26314  Subscriber
# 3527              40.717733             -74.043845   26311  Subscriber
# 17877             40.719586             -74.043117   29595  Subscriber
# 20279             40.728745             -74.032108   26300  Subscriber
# 23835             40.712419             -74.038526   29490  Subscriber
# 113               40.719586             -74.043117   26224  Subscriber
# 11462             40.716540             -74.049638   26152  Subscriber
# 3738              40.727224             -74.033759   29276  Subscriber
# 22324             40.716247             -74.033459   29586  Subscriber
# 28184             40.727224             -74.033759   26255  Subscriber
#
#        birth year  gender  day  start_hour  DOW
# 20148      1986.0       2   19          13    1
# 3527       1986.0       2    5           9    1
# 17877         NaN       0   17          14    6
# 20279      1981.0       1   19          17    1
# 23835      1975.0       2   22          11    4
# 113        1977.0       1    1           7    4
# 11462      1978.0       1   12           8    1
# 3738       1985.0       1    5          13    1
# 22324      1982.0       2   21           8    3
# 28184      1988.0       1   26          12    1

# %% [markdown]
# ---
#
# ## Quantitative Analysis
#
# - Count the number of trips and group by starting and ending station accordingly
# - Create a table of bike station, hour, total # of departure, total # of arrival, # of bikes at the dock, and lat/long; assuming there are 20 bikes at the beginning of the day at 12 a.m.

# %%
uni_dep_stations = df[['start station id', 'start station name', 'start station latitude', 'start station longitude']].drop_duplicates()
uni_arv_stations = df[['end station id', 'end station name', 'end station latitude', 'end station longitude']].drop_duplicates()

# %%
uni_dep_stations.shape
# Out:
# (49, 4)

# %%
uni_arv_stations.shape
# Out:
# (69, 4)

# %%
start_count = df.groupby("start station id").size().reset_index(name = "departure_cnt").\
                sort_values(by = "departure_cnt", ascending = False)
start_count = start_count.merge(uni_dep_stations, how = "left", left_on = "start station id", right_on = "start station id")
start_count
# Out:
#     start station id  departure_cnt       start station name  \
# 0               3186           4079            Grove St PATH
# 1               3203           2415            Hamilton Park
# 2               3183           2146           Exchange Place
# 3               3195           1672                  Sip Ave
# 4               3202           1487             Newport PATH
# 5               3267           1402             Morris Canal
# 6               3213           1079           Van Vorst Park
# 7               3211           1061               Newark Ave
# 8               3187           1008                Warren St
# 9               3199            951             Newport Pkwy
# 10              3276            922         Marin Light Rail
# 11              3184            921              Paulus Hook
# 12              3214            917         Essex Light Rail
# 13              3185            910                City Hall
# 14              3209            882             Brunswick St
# 15              3272            841             Jersey & 3rd
# 16              3275            779           Columbus Drive
# 17              3192            770       Liberty Light Rail
# 18              3270            766          Jersey & 6th St
# 19              3269            732          Brunswick & 6th
# 20              3194            645          McGinley Square
# 21              3205            643        JC Medical Center
# 22              3273            607             Manila & 1st
# 23              3279            536              Dixon Mills
# 24              3207            514              Oakland Ave
# 25              3278            468         Monmouth and 6th
# 26              3225            384    Baldwin at Montgomery
# 27              3210            335           Pershing Field
# 28              3206            293                  Hilltop
# 29              3212            287          Christ Hospital
# 30              3198            287         Heights Elevator
# 31              3196            278           Riverview Park
# 32              3268            269           Lafayette Park
# 33              3193            261             Lincoln Park
# 34              3280            249              Astor Place
# 35              3220            234        5 Corners Library
# 36              3481            225                  York St
# 37              3281            199      Leonard Gordon Park
# 38              3201            163                   Dey St
# 39              3277            135  Communipaw & Berry Lane
# 40              3190            123     Garfield Ave Station
# 41              3191             65                 Union St
# 42              3188             57                     NJCU
# 43              3200             31           MLK Light Rail
# 44              3189             27     West Side Light Rail
# 45              3271             21      Danforth Light Rail
# 46              3216             20            Columbia Park
# 47              3217             13             Bayside Park
# 48              3274             10           Bethune Center
#
#     start station latitude  start station longitude
# 0                40.719586               -74.043117
# 1                40.727596               -74.044247
# 2                40.716247               -74.033459
# 3                40.730743               -74.063784
# 4                40.727224               -74.033759
# 5                40.712419               -74.038526
# 6                40.718489               -74.047727
# 7                40.721525               -74.046305
# 8                40.721124               -74.038051
# 9                40.728745               -74.032108
# 10               40.714584               -74.042817
# 11               40.714145               -74.033552
# 12               40.712774               -74.036486
# 13               40.717733               -74.043845
# 14               40.724176               -74.050656
# 15               40.723332               -74.045953
# 16               40.718355               -74.038914
# 17               40.711242               -74.055701
# 18               40.725289               -74.045572
# 19               40.726012               -74.050389
# 20               40.725340               -74.067622
# 21               40.716540               -74.049638
# 22               40.721651               -74.042884
# 23               40.721630               -74.049968
# 24               40.737604               -74.052478
# 25               40.725685               -74.048790
# 26               40.723659               -74.064194
# 27               40.742677               -74.051789
# 28               40.731169               -74.057574
# 29               40.734786               -74.050444
# 30               40.748716               -74.040443
# 31               40.744319               -74.043991
# 32               40.713464               -74.062859
# 33               40.724605               -74.078406
# 34               40.719282               -74.071262
# 35               40.734961               -74.059503
# 36               40.716490               -74.041050
# 37               40.745910               -74.057271
# 38               40.737711               -74.066921
# 39               40.714358               -74.066611
# 40               40.710467               -74.070039
# 41               40.718211               -74.083639
# 42               40.710109               -74.085849
# 43               40.711130               -74.078885
# 44               40.714402               -74.088772
# 45               40.692640               -74.088012
# 46               40.697030               -74.096937
# 47               40.698651               -74.082080
# 48               40.704958               -74.085931

# %%
end_count = df.groupby("end station id").size().reset_index(name = "arrival_cnt").\
                sort_values(by = "arrival_cnt", ascending = False)
end_count = end_count.merge(uni_arv_stations, how = "left", left_on = "end station id", right_on = "end station id")
end_count
# Out:
#     end station id  arrival_cnt            end station name  \
# 0             3186         5005               Grove St PATH
# 1             3183         2585              Exchange Place
# 2             3203         2044               Hamilton Park
# 3             3202         1491                Newport PATH
# 4             3195         1421                     Sip Ave
# 5             3267         1154                Morris Canal
# 6             3211          958                  Newark Ave
# 7             3185          950                   City Hall
# 8             3213          947              Van Vorst Park
# 9             3214          924            Essex Light Rail
# 10            3187          911                   Warren St
# 11            3184          866                 Paulus Hook
# 12            3276          860            Marin Light Rail
# 13            3199          846                Newport Pkwy
# 14            3209          786                Brunswick St
# 15            3192          769          Liberty Light Rail
# 16            3272          757                Jersey & 3rd
# 17            3269          725             Brunswick & 6th
# 18            3275          713              Columbus Drive
# 19            3270          650             Jersey & 6th St
# 20            3205          646           JC Medical Center
# 21            3273          596                Manila & 1st
# 22            3278          557            Monmouth and 6th
# 23            3197          525                Hs Don't Use
# 24            3194          516             McGinley Square
# 25            3279          461                 Dixon Mills
# 26            3480          417                WS Don't Use
# 27            3207          378                 Oakland Ave
# 28            3225          301       Baldwin at Montgomery
# 29            3210          296              Pershing Field
# ..             ...          ...                         ...
# 39            3281          168         Leonard Gordon Park
# 40            3201          150                      Dey St
# 41            3212          150             Christ Hospital
# 42            3277          127     Communipaw & Berry Lane
# 43            3190          115        Garfield Ave Station
# 44            3188           65                        NJCU
# 45            3191           64                    Union St
# 46            3189           42        West Side Light Rail
# 47            3271           31         Danforth Light Rail
# 48            3216           22               Columbia Park
# 49            3200           21              MLK Light Rail
# 50            3217           17                Bayside Park
# 51            3426           10                  JCBS Depot
# 52            3274            8              Bethune Center
# 53             267            3          Broadway & W 36 St
# 54            3002            3  South End Ave & Liberty St
# 55             295            3        Pike St & E Broadway
# 56             514            2            12 Ave & W 40 St
# 57             525            2            W 34 St & 11 Ave
# 58             309            2         Murray St & West St
# 59            3461            1    Murray St & Greenwich St
# 60            3436            1    Greenwich St & Hubert St
# 61             152            1       Warren St & Church St
# 62             327            1    Vesey Pl & River Terrace
# 63             377            1            6 Ave & Canal St
# 64             428            1              E 3 St & 1 Ave
# 65             435            1             W 21 St & 6 Ave
# 66             508            1            W 46 St & 11 Ave
# 67            3167            1     Amsterdam Ave & W 73 St
# 68             128            1    MacDougal St & Prince St
#
#     end station latitude  end station longitude
# 0              40.719586             -74.043117
# 1              40.716247             -74.033459
# 2              40.727596             -74.044247
# 3              40.727224             -74.033759
# 4              40.730743             -74.063784
# 5              40.712419             -74.038526
# 6              40.721525             -74.046305
# 7              40.717733             -74.043845
# 8              40.718489             -74.047727
# 9              40.712774             -74.036486
# 10             40.721124             -74.038051
# 11             40.714145             -74.033552
# 12             40.714584             -74.042817
# 13             40.728745             -74.032108
# 14             40.724176             -74.050656
# 15             40.711242             -74.055701
# 16             40.723332             -74.045953
# 17             40.726012             -74.050389
# 18             40.718355             -74.038914
# 19             40.725289             -74.045572
# 20             40.716540             -74.049638
# 21             40.721651             -74.042884
# 22             40.725685             -74.048790
# 23             40.719252             -74.034234
# 24             40.725340             -74.067622
# 25             40.721630             -74.049968
# 26              0.000000               0.000000
# 27             40.737604             -74.052478
# 28             40.723659             -74.064194
# 29             40.742677             -74.051789
# ..                   ...                    ...
# 39             40.745910             -74.057271
# 40             40.737711             -74.066921
# 41             40.734786             -74.050444
# 42             40.714358             -74.066611
# 43             40.710467             -74.070039
# 44             40.710109             -74.085849
# 45             40.718211             -74.083639
# 46             40.714402             -74.088772
# 47             40.692640             -74.088012
# 48             40.697030             -74.096937
# 49             40.711130             -74.078885
# 50             40.698651             -74.082080
# 51             40.709651             -74.068601
# 52             40.704958             -74.085931
# 53             40.750977             -73.987654
# 54             40.711512             -74.015756
# 55             40.714067             -73.992939
# 56             40.760875             -74.002777
# 57             40.755942             -74.002116
# 58             40.714979             -74.013012
# 59             40.714852             -74.011223
# 60             40.721319             -74.010065
# 61             40.714740             -74.009106
# 62             40.715338             -74.016584
# 63             40.722438             -74.005664
# 64             40.724677             -73.987834
# 65             40.741740             -73.994156
# 66             40.763414             -73.996674
# 67             40.779668             -73.980930
# 68             40.727103             -74.002971
#
# [69 rows x 5 columns]

# %%
# Calculate end-of-hour bike balance in each station
